# %% [markdown]
# ## Datos a limpiar

# %%
# Tratamiento de datos
import pandas as pd
pd.set_option('display.max_columns', 25)

# Exploración de archivos
import sys
sys.path.append('../')

# Funciones personalizadas
from src import sp_limpieza as sl

# %%
df_raw = pd.read_csv('../data/data_raw.csv')
df_raw.sample(5)
# Out:
#       User Id Group  Visit Date  Conversion Product Category Product Id  \
# 290       291     A  2022-01-22           1             HOME      P1801
# 625       626     A  2022-01-22           0           SPORTS      P1455
# 161       162     B  2022-01-01           0      ELECTRONICS      P1252
# 1218     1219     B  2022-02-10           0           SPORTS      P1081
# 1266     1267     A  2022-01-23           0            BOOKS      P1333
#
#      Product Name  Quantity   Price Discount Total Value Payment Method  \
# 290          Lamp         2  100,22     0,16      168,37  Bank Transfer
# 625      Football         0  249,44     0,18         0,0            NaN
# 161    Smartphone         0  722,39      0,0         0,0            NaN
# 1218     Football         0   63,54      0,2         0,0            NaN
# 1266      Mystery         0   31,07     0,11         0,0            NaN
#
#      Shipping Method   Region  Customer Age Customer Gender  Device  \
# 290         Same day  Central          68.0               M  TABLET
# 625              NaN     West          38.0               M  Mobile
# 161              NaN    North          45.0               F  Mobile
# 1218             NaN     East          50.0               M  Mobile
# 1266             NaN     East          40.0               F  TABLET
#
#       Session Duration Coupon Used       Browser Referral Source
# 290                 11         Yes       Eddddge            PAID
# 625                  8         NaN  Firefoxxxxxx          Social
# 161                  4         NaN    Safaaaaari            PAID
# 1218                16         NaN     Ottttther           Email
# 1266                21         NaN      Chrooome         Organic

# %%
df = df_raw.copy()
df.columns = df.columns.str.replace(' ', '_').str.lower()

# %%
df.columns
# Out:
# Index(['user_id', 'group', 'visit_date', 'conversion', 'product_category',
#        'product_id', 'product_name', 'quantity', 'price', 'discount',
#        'total_value', 'payment_method', 'shipping_method', 'region',
#        'customer_age', 'customer_gender', 'device', 'session_duration',
#        'coupon_used', 'browser', 'referral_source'],
#       dtype='str')

# %%
df['visit_date']  = pd.to_datetime(df['visit_date'], format= '%Y-%m-%d')

# %%
df['conversion_str'] = df['conversion'].apply(lambda x: 'yes' if x == 1 else 'no')

# %%
df['product_category'] = df['product_category'].str.lower()

# %%
df['product_category'] = df['product_category'].str.replace('fashhion', 'fashion')

# %%
df['product_id'] = df['product_id'].str.replace('P', '')
df['product_id'] = df['product_id'].astype('int64')

# %%
sl.minus (df)
sl.comas (df)
sl.espacios (df)

# %% [markdown]
# - **Browser** -> Cambiar las categorías, están mal escritas, hacemos un map

# %%
df['browser'].unique()
# Out:
# <StringArray>
# ['safaaaaari', 'ottttther', 'firefoxxxxxx', 'eddddge', 'chrooome']
# Length: 5, dtype: str

# %%
dicc_map = {
    'safaaaaari' : 'safari', 
    'ottttther' : 'other', 
    'firefoxxxxxx' : 'firefox', 
    'eddddge' : 'edge', 
    'chrooome' : 'chrome'
}

# %%
df['browser'] = df['browser'].map(dicc_map)

# %%
df.sample(5)
# Out:
#       user_id group visit_date  conversion product_category  product_id  \
# 465       466     a 2022-02-14           0             home        1132
# 1289     1290     a 2022-02-07           0          fashion        1867
# 589       590     a 2022-03-06           0           beauty        1842
# 169       170     b 2022-01-09           0           sports        1414
# 529       530     b 2022-02-18           0             toys        1349
#
#      product_name  quantity   price  discount  total_value payment_method  \
# 465         table         0  284.37      0.25          0.0            NaN
# 1289      t-shirt         0  179.28      0.19          0.0            NaN
# 589       mascara         0   88.51      0.06          0.0            NaN
# 169      football         0  143.64      0.01          0.0            NaN
# 529    board_game         0   97.06      0.27          0.0            NaN
#
#      shipping_method   region  customer_age customer_gender   device  \
# 465              NaN    south          32.0               f  desktop
# 1289             NaN  central          51.0               m  desktop
# 589              NaN    south          22.0               m   mobile
# 169              NaN     east           NaN               f   tablet
# 529              NaN  central          29.0               f   mobile
#
#       session_duration coupon_used  browser referral_source conversion_str
# 465                 13         NaN    other            paid             no
# 1289                 8         NaN     edge         organic             no
# 589                 27         NaN    other            paid             no
# 169                 14         NaN  firefox          social             no
# 529                 12         NaN   chrome           email             no

# %%
df.to_csv('../data/datos_limpios.csv', index=False)
